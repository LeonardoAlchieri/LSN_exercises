# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 4</span>

# %% [markdown]
# ## Es 1

# %%
import matplotlib.pyplot as plt

import numpy as np
plt.style.use('classic')

# %%
temp = np.loadtxt('output_temp.dat')
x_temp = np.arange(len(f1))

# %%
plt.plot(x_temp, temp)
plt.axhline(1.1, color='red')
plt.show()

# %%
f2 = np.loadtxt('ave_ekin.out', skiprows=1)
x2 = np.arange(100)

f3 = np.loadtxt('ave_epot.out', skiprows=1)
x3 = np.arange(100)

f4 = np.loadtxt('ave_etot.out', skiprows=1)
x4 = np.arange(100)

f2.shape
# Out:
# (100, 2)

# %%
plt.errorbar(x2, f2[:,0], yerr=f2[:,1], label='Kinetic energy')
plt.errorbar(x3, f3[:,0], yerr=f3[:,1], label='Potential energy')
plt.errorbar(x4, f4[:,0], yerr=f4[:,1], label='Total energy')

plt.xlabel('block')
plt.ylabel('Energy')

plt.legend(loc="best")

#plt.axhline(1.4, color='red')
plt.show()
