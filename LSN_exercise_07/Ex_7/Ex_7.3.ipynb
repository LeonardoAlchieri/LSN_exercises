# %% [markdown]
# # Ex 07.3
#
# <span style="color:red">Include the calculation of the radial distribution function, $g(r)$, inside the previously used Molecular Dynamics code</span>.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# The ```MolecularDynamics_NVE``` code here present is modified in order to evaluate _only_ the $g(r)$. It is _non modificable_ for practical reasons.
#
# The variables are set to run for a liquid with as the one above.

# %%
system('MolecularDynamics_NVE/simulation.exe')

# %%
md_g = np.loadtxt('MolecularDynamics_NVE/output.gave.0')

print(md_g.shape)
# Out:
# (100, 3)

# %%
#fattore_di_scala = max(ave_liquid[1:,1])/max(md_g[1:,1])
#print(fattore_di_scala, 1/fattore_di_scala)

# %%
plt.style.use('classic')
plt.figure(num=None, figsize=(10, 8), dpi=100, facecolor='w', edgecolor='k')

plt.errorbar(md_g[:,0], md_g[:,1], yerr=md_g[:,2], color='red', label='NVE')
plt.errorbar(ave_liquid[:,0], ave_liquid[:,1], yerr=ave_liquid[:,2], label='NVT')
plt.xlabel('$r/\sigma$')
plt.ylabel('$g(r)$')
plt.title('$g(r)$ for a Liquid')
plt.legend(loc='best')
plt.show()
